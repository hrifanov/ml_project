# %% [markdown]
# <a href="https://colab.research.google.com/github/hrifanov/ml_project/blob/main/Sprint_6/contrastive_loss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install keras_vggface
# !pip install keras_applications
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras_vggface
#   Downloading keras_vggface-0.6-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from keras_vggface) (6.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.8/dist-packages (from keras_vggface) (1.21.6)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from keras_vggface) (1.15.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.8/dist-packages (from keras_vggface) (7.1.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.8/dist-packages (from keras_vggface) (3.1.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.8/dist-packages (from keras_vggface) (1.7.3)
# Requirement already satisfied: keras in /usr/local/lib/python3.8/dist-packages (from keras_vggface) (2.9.0)
# Installing collected packages: keras_vggface
# Successfully installed keras_vggface-0.6
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras_applications
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 KB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: h5py in /usr/local/lib/python3.8/dist-packages (from keras_applications) (3.1.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.8/dist-packages (from keras_applications) (1.21.6)
# Installing collected packages: keras_applications
# Successfully installed keras_applications-1.0.8

# %%
# !pip show keras_vggface
# Out:
# Name: keras-vggface
# Version: 0.6
# Summary: VGGFace implementation with Keras framework
# Home-page: https://github.com/rcmalli/keras-vggface
# Author: Refik Can MALLI
# Author-email: mallir@itu.edu.tr
# License: MIT
# Location: /usr/local/lib/python3.8/dist-packages
# Requires: h5py, keras, numpy, pillow, pyyaml, scipy, six
# Required-by:

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications import resnet50
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow import convert_to_tensor
import tensorflow.keras.backend as K
from matplotlib import pyplot as plt
from sklearn.utils import shuffle
from sklearn.model_selection import LeaveOneOut, KFold
import keras
from keras.models import load_model
from keras_vggface.vggface import VGGFace
from keras_vggface.utils import preprocess_input
import pandas as pd
import numpy as np
import cv2
import os
import random

# %%
images_path = "drive/MyDrive/Dataset/img_celeba_cropped/"
celeb = "drive/MyDrive/Dataset/colab_df.txt"
openface = "/content/drive/MyDrive/openface/nn4.small2.v1.t7"

# %%
image_shape=(224, 224, 3)

batch_size=16
lr=0.00001

# %%
balanced_df = pd.read_csv(celeb)
balanced_df["left"] = balanced_df["left"].str.replace("../Dataset/img_celeba_cropped/", "drive/MyDrive/Dataset/img_celeba_cropped/")
balanced_df["right"] = balanced_df["right"].str.replace("../Dataset/img_celeba_cropped/", "drive/MyDrive/Dataset/img_celeba_cropped/")
balanced_df
# Out:
# <ipython-input-4-ae9cb30fda96>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   balanced_df["left"] = balanced_df["left"].str.replace("../Dataset/img_celeba_cropped/", "drive/MyDrive/Dataset/img_celeba_cropped/")
# <ipython-input-4-ae9cb30fda96>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   balanced_df["right"] = balanced_df["right"].str.replace("../Dataset/img_celeba_cropped/", "drive/MyDrive/Dataset/img_celeba_cropped/")
#                                                    left  \
# 0     drive/MyDrive/Dataset/img_celeba_cropped/00497...
# 1     drive/MyDrive/Dataset/img_celeba_cropped/00497...
# 2     drive/MyDrive/Dataset/img_celeba_cropped/00310...
# 3     drive/MyDrive/Dataset/img_celeba_cropped/00310...
# 4     drive/MyDrive/Dataset/img_celeba_cropped/00474...
# ...                                                 ...
# 1195  drive/MyDrive/Dataset/img_celeba_cropped/00070...
# 1196  drive/MyDrive/Dataset/img_celeba_cropped/00182...
# 1197  drive/MyDrive/Dataset/img_celeba_cropped/00182...
# 1198  drive/MyDrive/Dataset/img_celeba_cropped/00487...
# 1199  drive/MyDrive/Dataset/img_celeba_cropped/00487...
#
#                                                   right  label
# 0     drive/MyDrive/Dataset/img_celeba_cropped/00237...      1
# 1     drive/MyDrive/Dataset/img_celeba_cropped/00231...      0
# 2     drive/MyDrive/Dataset/img_celeba_cropped/00094...      1
# 3     drive/MyDrive/Dataset/img_celeba_cropped/00374...      0
# 4     drive/MyDrive/Dataset/img_celeba_cropped/00482...      1
# ...                                                 ...    ...
# 1195  drive/MyDrive/Dataset/img_celeba_cropped/00160...      0
# 1196  drive/MyDrive/Dataset/img_celeba_cropped/00325...      1
# 1197  drive/MyDrive/Dataset/img_celeba_cropped/00301...      0
# 1198  drive/MyDrive/Dataset/img_celeba_cropped/00243...      1
# 1199  drive/MyDrive/Dataset/img_celeba_cropped/00161...      0
#
# [1200 rows x 3 columns]

# %%
train_df, test_df, validate_df = np.split(balanced_df, [int(.8*len(balanced_df)), int(.9*len(balanced_df))])

# %%
X_train = train_df[["left", "right"]]
Y_train_label = train_df[["label"]]

X_test = test_df[["left", "right"]]
Y_test_label = test_df[["label"]]

X_val = validate_df[["left", "right"]]
Y_val_label = validate_df[["label"]]

# %%
print('=====Training=====')
print(X_train.shape)
print(Y_train_label.shape)

print('=====Testing=====')
print(X_test.shape)
print(Y_test_label.shape)

print('=====Validate=====')
print(X_val.shape)
print(Y_val_label.shape)
# Out:
# =====Training=====
# (960, 2)
# (960, 1)
# =====Testing=====
# (120, 2)
# (120, 1)
# =====Validate=====
# (120, 2)
# (120, 1)

# %%
#def preprocessing(left, right):
def preprocessing(img):
    #return convert_to_img(left), convert_to_img(right)
    return convert_to_img(img)


def convert_to_img(img_path):
    #img = tf.io.read_file(img_path)
    img = cv2.imread(img_path)
    img = img.astype("float32")
    #img = img/255
    #img = tf.image.decode_jpeg(img, channels = 3)
    #img = tf.image.convert_image_dtype(img, tf.float32)
    img = preprocess_input(img, version=2)

    return img

def label_preprocessing(label):
    return tf.cast(label, tf.float32)

# %%
def create_dataset(features, labels):

    left = features["left"].apply(convert_to_img)
    right = features["right"].apply(convert_to_img)
    left = left.tolist()
    right = right.tolist()

    feature_ds = tf.data.Dataset.from_tensor_slices((left, right))
    labels_ds = tf.data.Dataset.from_tensor_slices(labels.values)
    
    #data_augmentation = keras.Sequential([layers.RandomFlip("horizontal"),
    #                                      layers.RandomRotation(0.1),
    #                                      layers.RandomZoom(0.1)])
    
    #feature_ds = feature_ds.map(preprocessing)
    labels_ds = labels_ds.map(label_preprocessing)
    
    #normalization_layer = tf.keras.layers.Rescaling(1./255)
    #feature_ds = feature_ds.map(lambda image_left, image_right: (normalization_layer(image_left), normalization_layer(image_right)))
    
    dataset = tf.data.Dataset.zip((feature_ds, labels_ds))
    dataset = dataset.batch(batch_size, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
    
    return dataset

# %%
train_ds = create_dataset(X_train, Y_train_label)
test_ds = create_dataset(X_test, Y_test_label)
val_ds = create_dataset(X_val, Y_val_label)
train_ds
# Out:
# <PrefetchDataset element_spec=((TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None)), TensorSpec(shape=(None, 1), dtype=tf.float32, name=None))>

# %%
left_input = layers.Input(shape=image_shape, name='left_input')
right_input = layers.Input(shape=image_shape, name='right_input')

# %%
def euclidean_distance(vects):
    x, y = vects
    sum_square = tf.math.reduce_sum(tf.math.square(x - y), axis=1, keepdims=True)
    return tf.math.sqrt(tf.math.maximum(sum_square, tf.keras.backend.epsilon()))

# %%
def tower_network():
  input = layers.Input((image_shape))
  scaled_input = layers.Rescaling(1/255, 0.0)(input)

  x = layers.Conv2D(32, (10, 10), activation="relu", padding="same")(scaled_input)
  x = layers.MaxPool2D((2, 2))(x)

  x = layers.Conv2D(64, (5, 5), activation="relu", padding="same")(x)
  x = layers.MaxPool2D((2, 2))(x)

  x = layers.Conv2D(128, (3, 3), activation="relu", padding="same")(x)
  x = layers.MaxPool2D((2, 2))(x)

  x = layers.GlobalAveragePooling2D()(x)

  x = layers.Flatten()(x)
  output = layers.Dense(64, activation="relu")(x)
  
  return Model(inputs=input, outputs=output, name="tower_network")

# %%
def vgg_face_tower():
  input = layers.Input((image_shape))
  base = VGGFace(input_tensor = input, model="resnet50", input_shape=image_shape, include_top = False)

  for layer in base.layers:
    layer.trainable = False

  for layer in base.layers:
    print(layer.name, layer.trainable)

  x = layers.Flatten()(base.output)
  output = layers.Dense(64, activation="relu")(x)

  return Model(input, output, name="vgg_face_tower")

# %%
def siamese_lambda_network():
    embedding_network = vgg_face_tower()
    # initializing the left "tower"
    left_tower_input = layers.Input(shape=(224,224,3), name = "left_tower")
    left_tower = embedding_network(left_tower_input)
    # initializing the right "tower"
    right_tower_input = layers.Input(shape=(224,224,3), name = "right_tower")
    right_tower = embedding_network(right_tower_input)
    # merge, normalize, and output
    merge_layer = layers.Lambda(euclidean_distance, name = "lambda_layer")([left_tower, right_tower])
    
    x = layers.Dense(64, activation = "relu")(merge_layer)
    
    output_layer = layers.Dense(1, activation = "sigmoid")(x)
    
    return Model([left_tower_input, right_tower_input], output_layer, name = "siamese_lambda_network")

# %%
model = siamese_lambda_network()
# Out:
# input_1 False
# conv1/7x7_s2 False
# conv1/7x7_s2/bn False
# activation False
# max_pooling2d False
# conv2_1_1x1_reduce False
# conv2_1_1x1_reduce/bn False
# activation_1 False
# conv2_1_3x3 False
# conv2_1_3x3/bn False
# activation_2 False
# conv2_1_1x1_increase False
# conv2_1_1x1_proj False
# conv2_1_1x1_increase/bn False
# conv2_1_1x1_proj/bn False
# add False
# activation_3 False
# conv2_2_1x1_reduce False
# conv2_2_1x1_reduce/bn False
# activation_4 False
# conv2_2_3x3 False
# conv2_2_3x3/bn False
# activation_5 False
# conv2_2_1x1_increase False
# conv2_2_1x1_increase/bn False
# add_1 False
# activation_6 False
# conv2_3_1x1_reduce False
# conv2_3_1x1_reduce/bn False
# activation_7 False
# conv2_3_3x3 False
# conv2_3_3x3/bn False
# activation_8 False
# conv2_3_1x1_increase False
# conv2_3_1x1_increase/bn False
# add_2 False
# activation_9 False
# conv3_1_1x1_reduce False
# conv3_1_1x1_reduce/bn False
# activation_10 False
# conv3_1_3x3 False
# conv3_1_3x3/bn False
# activation_11 False
# conv3_1_1x1_increase False
# conv3_1_1x1_proj False
# conv3_1_1x1_increase/bn False
# conv3_1_1x1_proj/bn False
# add_3 False
# activation_12 False
# conv3_2_1x1_reduce False
# conv3_2_1x1_reduce/bn False
# activation_13 False
# conv3_2_3x3 False
# conv3_2_3x3/bn False
# activation_14 False
# conv3_2_1x1_increase False
# conv3_2_1x1_increase/bn False
# add_4 False
# activation_15 False
# conv3_3_1x1_reduce False
# conv3_3_1x1_reduce/bn False
# activation_16 False
# conv3_3_3x3 False
# conv3_3_3x3/bn False
# activation_17 False
# conv3_3_1x1_increase False
# conv3_3_1x1_increase/bn False
# add_5 False
# activation_18 False
# conv3_4_1x1_reduce False
# conv3_4_1x1_reduce/bn False
# activation_19 False
# conv3_4_3x3 False
# conv3_4_3x3/bn False
# activation_20 False
# conv3_4_1x1_increase False
# conv3_4_1x1_increase/bn False
# add_6 False
# activation_21 False
# conv4_1_1x1_reduce False
# conv4_1_1x1_reduce/bn False
# activation_22 False
# conv4_1_3x3 False
# conv4_1_3x3/bn False
# activation_23 False
# conv4_1_1x1_increase False
# conv4_1_1x1_proj False
# conv4_1_1x1_increase/bn False
# conv4_1_1x1_proj/bn False
# add_7 False
# activation_24 False
# conv4_2_1x1_reduce False
# conv4_2_1x1_reduce/bn False
# activation_25 False
# conv4_2_3x3 False
# conv4_2_3x3/bn False
# activation_26 False
# conv4_2_1x1_increase False
# conv4_2_1x1_increase/bn False
# add_8 False
# activation_27 False
# conv4_3_1x1_reduce False
# conv4_3_1x1_reduce/bn False
# activation_28 False
# conv4_3_3x3 False
# conv4_3_3x3/bn False
# activation_29 False
# conv4_3_1x1_increase False
# conv4_3_1x1_increase/bn False
# add_9 False
# activation_30 False
# conv4_4_1x1_reduce False
# conv4_4_1x1_reduce/bn False
# activation_31 False
# conv4_4_3x3 False
# conv4_4_3x3/bn False
# activation_32 False
# conv4_4_1x1_increase False
# conv4_4_1x1_increase/bn False
# add_10 False
# activation_33 False
# conv4_5_1x1_reduce False
# conv4_5_1x1_reduce/bn False
# activation_34 False
# conv4_5_3x3 False
# conv4_5_3x3/bn False
# activation_35 False
# conv4_5_1x1_increase False
# conv4_5_1x1_increase/bn False
# add_11 False
# activation_36 False
# conv4_6_1x1_reduce False
# conv4_6_1x1_reduce/bn False
# activation_37 False
# conv4_6_3x3 False
# conv4_6_3x3/bn False
# activation_38 False
# conv4_6_1x1_increase False
# conv4_6_1x1_increase/bn False
# add_12 False
# activation_39 False
# conv5_1_1x1_reduce False
# conv5_1_1x1_reduce/bn False
# activation_40 False
# conv5_1_3x3 False
# conv5_1_3x3/bn False
# activation_41 False
# conv5_1_1x1_increase False
# conv5_1_1x1_proj False
# conv5_1_1x1_increase/bn False
# conv5_1_1x1_proj/bn False
# add_13 False
# activation_42 False
# conv5_2_1x1_reduce False
# conv5_2_1x1_reduce/bn False
# activation_43 False
# conv5_2_3x3 False
# conv5_2_3x3/bn False
# activation_44 False
# conv5_2_1x1_increase False
# conv5_2_1x1_increase/bn False
# add_14 False
# activation_45 False
# conv5_3_1x1_reduce False
# conv5_3_1x1_reduce/bn False
# activation_46 False
# conv5_3_3x3 False
# conv5_3_3x3/bn False
# activation_47 False
# conv5_3_1x1_increase False
# conv5_3_1x1_increase/bn False
# add_15 False
# activation_48 False
# avg_pool False

# %%
def cont_loss(margin=1):
    def contrastive_loss(y_true, y_pred):
        square_pred = tf.math.square(y_pred)
        margin_square = tf.math.square(tf.math.maximum(margin - (y_pred), 0))
        return tf.math.reduce_mean(
            (1 - y_true) * square_pred + (y_true) * margin_square
        )

    return contrastive_loss

# %%
model.compile(loss=cont_loss(0.2), optimizer=Adam(learning_rate=lr))
model.summary()
# Out:
# Model: "siamese_lambda_network"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  left_tower (InputLayer)        [(None, 224, 224, 3  0           []
#                                 )]
#
#  right_tower (InputLayer)       [(None, 224, 224, 3  0           []
#                                 )]
#
#  vgg_face_tower (Functional)    (None, 64)           23692288    ['left_tower[0][0]',
#                                                                   'right_tower[0][0]']
#
#  lambda_layer (Lambda)          (None, 1)            0           ['vgg_face_tower[0][0]',
#                                                                   'vgg_face_tower[1][0]']
#
#  dense_1 (Dense)                (None, 64)           128         ['lambda_layer[0][0]']
#
#  dense_2 (Dense)                (None, 1)            65          ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 23,692,481
# Trainable params: 131,329
# Non-trainable params: 23,561,152
# __________________________________________________________________________________________________

# %%
callback_list = []

early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=5)
callback_list.append(early_stopping)

# %%
model_fit = model.fit(train_ds, validation_data=val_ds, epochs=10, callbacks=callback_list)
# Out:
# Epoch 1/10
# 60/60 [==============================] - 16s 154ms/step - loss: 0.0170 - val_loss: 0.0162
# Epoch 2/10
# 60/60 [==============================] - 6s 97ms/step - loss: 0.0157 - val_loss: 0.0146
# Epoch 3/10
# 60/60 [==============================] - 6s 97ms/step - loss: 0.0136 - val_loss: 0.0122
# Epoch 4/10
# 60/60 [==============================] - 7s 109ms/step - loss: 0.0109 - val_loss: 0.0097
# Epoch 5/10
# 60/60 [==============================] - 6s 100ms/step - loss: 0.0085 - val_loss: 0.0081
# Epoch 6/10
# 60/60 [==============================] - 6s 98ms/step - loss: 0.0072 - val_loss: 0.0075
# Epoch 7/10
# 60/60 [==============================] - 6s 97ms/step - loss: 0.0066 - val_loss: 0.0072
# Epoch 8/10
# 60/60 [==============================] - 6s 98ms/step - loss: 0.0062 - val_loss: 0.0071
# Epoch 9/10
# 60/60 [==============================] - 6s 99ms/step - loss: 0.0058 - val_loss: 0.0070
# Epoch 10/10
# 60/60 [==============================] - 6s 99ms/step - loss: 0.0055 - val_loss: 0.0069

# %%
plt.plot(model_fit.history['loss'])
plt.plot(model_fit.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.grid()

plt.show()

# %%
def create_dataset_no_labels(features):
    left = features["left"].apply(convert_to_img)
    right = features["right"].apply(convert_to_img)
    left = left.tolist()
    right = right.tolist()

    feature_ds = tf.data.Dataset.from_tensor_slices((left, right))
    
    feature_ds = feature_ds.batch(batch_size, num_parallel_calls=tf.data.AUTOTUNE)
    feature_ds = feature_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
    
    return feature_ds

def create_singular_dataset(feature):
    dataset = tf.data.Dataset.from_tensor_slices(feature.values)
    dataset = dataset.map(convert_to_img)
    dataset = dataset.batch(batch_size, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
    
    return dataset

# %%
#test_ds_left = create_singular_dataset(X_test['left'])
#test_ds_right = create_singular_dataset(X_test['right'])
test_labels = Y_test_label['label']

#test_ds_full = create_dataset_no_labels(X_test)

# %%
predictions = model.predict(test_ds)
# Out:
# 8/8 [==============================] - 2s 91ms/step

# %%
predictions_for_accuracy = predictions.flatten()
predictions_for_accuracy = predictions_for_accuracy.tolist()

# %%
len(predictions_for_accuracy)
# Out:
# 120

# %%
predictions_labels = pd.DataFrame({"labels":test_labels, 
                                   "predictions":predictions_for_accuracy})
predictions_labels
# Out:
#       labels  predictions
# 960        1     0.111394
# 961        0     0.035251
# 962        1     0.180495
# 963        0     0.038045
# 964        1     0.171513
# ...      ...          ...
# 1075       0     0.066931
# 1076       1     0.129994
# 1077       0     0.019106
# 1078       1     0.086206
# 1079       0     0.024320
#
# [120 rows x 2 columns]

# %%
predictions_labels_positive = predictions_labels["predictions"].loc[predictions_labels["labels"] == 1]
predictions_labels_negative = predictions_labels["predictions"].loc[predictions_labels["labels"] == 0]
positive_mean = predictions_labels_positive.mean()
negative_mean = predictions_labels_negative.mean()
# Out:
# 960     0.111394
# 962     0.180495
# 964     0.171513
# 966     0.162353
# 968     0.121661
# 970     0.045208
# 972     0.111625
# 974     0.156262
# 976     0.054795
# 978     0.046386
# 980     0.255847
# 982     0.102900
# 984     0.086934
# 986     0.129993
# 988     0.137453
# 990     0.042471
# 992     0.064091
# 994     0.190746
# 996     0.110044
# 998     0.191834
# 1000    0.060318
# 1002    0.217169
# 1004    0.101406
# 1006    0.086425
# 1008    0.177158
# 1010    0.077135
# 1012    0.173007
# 1014    0.054536
# 1016    0.159326
# 1018    0.044889
# 1020    0.082534
# 1022    0.206270
# 1024    0.110054
# 1026    0.091910
# 1028    0.164205
# 1030    0.048497
# 1032    0.128132
# 1034    0.147387
# 1036    0.057936
# 1038    0.135502
# 1040    0.132523
# 1042    0.098147
# 1044    0.092007
# 1046    0.033920
# 1048    0.175711
# 1050    0.126521
# 1052    0.053640
# 1054    0.167318
# 1056    0.167650
# 1058    0.125432
# 1060    0.047475
# 1062    0.244379
# 1064    0.095341
# 1066    0.223548
# 1068    0.156617
# 1070    0.078182
# 1072    0.071172
# 1074    0.106617
# 1076    0.129994
# 1078    0.086206
# Name: predictions, dtype: float64

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1, 1])
ax.boxplot([predictions_labels_negative, predictions_labels_positive])
plt.xticks([1, 2], ['Positive', 'Negative'])
ax.grid()
plt.show()

# %%
def compute_accuracy(y_true, y_pred, cutoff):
    pred = y_pred > cutoff
    return np.mean(pred == y_true), pred

# %%
cutoff = (positive_mean + negative_mean)/2

test_accuracy, y_pred = compute_accuracy(test_labels, predictions_for_accuracy, cutoff)
print(f'Accuracy: {test_accuracy*100:.2f}%')
# Out:
# Accuracy: 70.00%

# %%
def visualize(pairs, labels, to_show=6, num_col=3, predictions=None, test=False):

    num_row = to_show // num_col if to_show // num_col != 0 else 1

    to_show = num_row * num_col

    fig, axes = plt.subplots(num_row, num_col, figsize=(5, 5))
    for i in range(to_show):

        if num_row == 1:
            ax = axes[i % num_col]
        else:
            ax = axes[i // num_col, i % num_col]

        ax.imshow(tf.concat([cv2.cvtColor(cv2.imread(pairs["left"].iloc[i]), cv2.COLOR_BGR2RGB), cv2.cvtColor(cv2.imread(pairs["right"].iloc[i]), cv2.COLOR_BGR2RGB)], axis=1), cmap="gray")
        ax.set_axis_off()
        if test:
            ax.set_title("True: {} | Pred: {:.5f}".format(labels["label"].iloc[i], predictions[i][0]))
        else:
            ax.set_title("Label: {}".format(labels[i]))
    if test:
        plt.tight_layout(rect=(0, 0, 1.9, 1.9), w_pad=0.0)
    else:
        plt.tight_layout(rect=(0, 0, 1.5, 1.5))
    plt.show()

# %%
visualize(X_val, Y_val_label, to_show=18, num_col=3, predictions=predictions, test=True)

# %%
cutoff
# Out:
# 0.09421632859545451
